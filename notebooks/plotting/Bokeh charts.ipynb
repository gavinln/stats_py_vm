# %% [markdown]
# # Bokeh charts

# %%
import IPython
IPython.__version__
# Out:
# '4.1.1'

# %%
import bokeh
bokeh.__version__
# Out:
# '0.11.1'

# %% [markdown]
# High level interface re-written for version [0.10](http://bokeh.pydata.org/en/0.10.0/docs/releases/0.10.0.html)

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6ece5f1a-aa69-460e-9678-bf858c250ada">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Chart inputs
#
# Bokeh chart inpusts can be of two types
#
# * Array-like - [list][10], [tuple][20], [numpy.ndarray][30], [pandas.Series][40]
# * Table-like - records: list([dict][50]), columns: dict(list), [pandas.DataFrame][60]
#
# [10]: https://docs.python.org/2/tutorial/datastructures.html#more-on-lists
# [20]: https://docs.python.org/2/tutorial/datastructures.html#tuples-and-sequences
# [30]: http://docs.scipy.org/doc/numpy-1.10.0/reference/generated/numpy.ndarray.html#numpy-ndarray
# [40]: http://pandas.pydata.org/pandas-docs/version/0.17.1/dsintro.html#series-is-ndarray-like
#
# [50]: https://docs.python.org/2/tutorial/datastructures.html#dictionaries
# [60]: http://pandas.pydata.org/pandas-docs/version/0.17.1/dsintro.html#dataframe

# %%
from bokeh import charts

# %% [markdown]
# ## Scatter plot

# %%
from bokeh.sampledata.iris import flowers
flowers.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
p = charts.Scatter(flowers, x='petal_length', y='petal_width', color='species',
                   legend='top_left')
show(p)
# Out:
#     <div class="plotdiv" id="29e3a439-46f0-4a84-96e1-83254899722f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("29e3a439-46f0-4a84-96e1-83254899722f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '29e3a439-46f0-4a84-96e1-83254899722f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e1722293-26f5-4445-ab35-6ddcf2e50973":{"roots":{"references":[{"attributes":{"below":[{"id":"88ac77c6-8a29-44bd-b544-a0b24351a794","type":"LinearAxis"}],"left":[{"id":"b09c5c4d-e77f-4d50-9c4c-e1695dc182ee","type":"LinearAxis"}],"legend":"top_left","renderers":[{"id":"00acec77-7d68-49a3-b51e-83d01cf50163","type":"BoxAnnotation"},{"id":"cba5b1f5-29a0-4c35-867a-5bb2848d4459","type":"GlyphRenderer"},{"id":"d2fbf856-0e83-4266-9f26-1cdcaf45e4f9","type":"GlyphRenderer"},{"id":"cb195fa7-0aa6-4f6f-af8e-d6155b3518cc","type":"GlyphRenderer"},{"id":"ddca914c-de21-4a00-af7e-363d542aebee","type":"Legend"},{"id":"88ac77c6-8a29-44bd-b544-a0b24351a794","type":"LinearAxis"},{"id":"b09c5c4d-e77f-4d50-9c4c-e1695dc182ee","type":"LinearAxis"},{"id":"2b953cdf-3d2d-4837-a773-e9ffe792215b","type":"Grid"},{"id":"3f6ce776-ed8d-4fb1-931e-b19143814964","type":"Grid"}],"title_text_font_size":{"value":"14pt"},"tool_events":{"id":"49468289-4d92-40d6-8ccc-2251ceb2d684","type":"ToolEvents"},"tools":[{"id":"4c28c656-1c9a-487d-b0ff-a10f0169635a","type":"PanTool"},{"id":"d71c16df-7e04-4658-a06c-352b317bfe8a","type":"WheelZoomTool"},{"id":"da3d4f1a-9053-4e55-b99b-311f82e81fdd","type":"BoxZoomTool"},{"id":"93aa139f-bfe1-4f0c-ad20-26789c980b07","type":"PreviewSaveTool"},{"id":"be2af13f-c401-41f6-a53e-333734afc92e","type":"ResizeTool"},{"id":"d1c02972-8e0f-4089-b7ac-06cac6b38afe","type":"ResetTool"},{"id":"95057f76-cb48-44f5-896f-747371b3ee42","type":"HelpTool"}],"x_mapper_type":"auto","x_range":{"id":
type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c7b3b8f8-7100-4fff-8a5e-ed3b2914e152","type":"Rect"},{"attributes":{"below":[{"id":"e0868f0a-485f-472b-85fc-48d8ca3a5e59","type":"CategoricalAxis"}],"left":[{"id":"23893a7c-47bf-4bd4-803a-eb6e054c3ec2","type":"LinearAxis"}],"legend":"top_left","renderers":[{"id":"a3f5ef84-4e5f-4970-a111-1d84caa038e4","type":"GlyphRenderer"},{"id":"9e5d8b92-83ee-4523-996a-1331542a3eb5","type":"GlyphRenderer"},{"id":"2aab4933-82f7-46f2-9c6d-b2d9ac6be63c","type":"GlyphRenderer"},{"id":"7a39bb36-e734-4502-9cfe-a272eea98025","type":"GlyphRenderer"},{"id":"8681f1f9-04a3-4db4-be06-1d06f143dbe1","type":"G ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[19]</strong>&gt;</code></p>

# %% [markdown]
# ## Bar plots

# %%
from bokeh.sampledata.autompg import autompg
autompg.head()
# Out:
#    mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0   18    8    307  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1   15    8    350  165    3693   11.5  70       1          buick skylark 320
# 2   18    8    318  150    3436   11.0  70       1         plymouth satellite
# 3   16    8    304  150    3433   12.0  70       1              amc rebel sst
# 4   17    8    302  140    3449   10.5  70       1                ford torino

# %% [markdown]
# ### Grouped bar plots

# %%
p = charts.Bar(
    autompg, label='yr', values='mpg', agg='median', 
    group='origin', # Use the group feature
    title="Median MPG by YR, grouped by ORIGIN", legend='top_left', tools='crosshair'
)
show(p)
# Out:
#     <div class="plotdiv" id="b8f9f6cb-6d22-4e3c-ae54-2e71838e3ea2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b8f9f6cb-6d22-4e3c-ae54-2e71838e3ea2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b8f9f6cb-6d22-4e3c-ae54-2e71838e3ea2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c92cede0-615a-4688-b935-2726a413c7dc":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6900935d-9f09-43a6-9bf1-b07e21b8e56a","type":"Rect"},{"attributes":{"data_source":{"id":"00bee4a7-3e34-4106-9796-4abd53bac194","type":"ColumnDataSource"},"glyph":{"id":"d76ff34b-4970-4784-a35e-60dc14973c63","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"10183b46-0905-47d5-bd8a-30f53120d1fa","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c6b3a051-1d51-499c-ba70-bd0bac13efb1","type":"ColumnDataSource"},"glyph":{"id":"1c9d853c-5188-413c-bd7f-783bc6b9ca1a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4b9b34c2-3a40-45b2-8647-16adcb399826","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"479632d2-e25c-41ba-a46b-1bf0601de2b6","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"83e0420c-b61b-4629-9dc2-13f544030012","type":"Rect"},{"attributes":{"data_source":{"id":"cdb44d61-bb51-4e00-8f01-207700c0136a","type":"ColumnDataSource"},"glyph":{"id":"dd4b7236-a0c7-4830-88e7-9020877da32b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"dabc4a66-9d1d-4187-b2dd-abaf7b4a76df","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"63a3c618-6081-4854-967b-30be67f3bb47","type":"ColumnDataSource"},"glyph":{"id":"37cff346-8c55-49d9-93c3-54032b6bcdab","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6e912d43-e86d-45d8-827a-2ce222352db7","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1c6936c1-04ed-405c-ac55-409bdcdbc0fb","type":"ColumnDataSource"},"glyph":{"id":"bffa5cc0-d1ca-4e00-a1d2-b97f7f397bc4","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"38436eae-8b7f-40b3-83ce-4a6a066d936d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"type":"lognormal"}],"color":["#f22c40"],"fill_alpha":[0.6],"height":[5.0],"line_alpha":[1.0],"line_color":["black"],"type":["lognormal"],"width":[0.09500000000000003],"x":["2.415"],"y":[2.5]}},"id":"34f4a2d4-3363-4ccf-aff4-e13358eaa9dd","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"
...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[24]</strong>&gt;</code></p>

# %% [markdown]
# ## Histogram

# %%
import pandas as pd
import numpy as np

# build some distributions
mu, sigma = 0, 0.5
normal = pd.DataFrame({'value': np.random.normal(mu, sigma, 1000), 'type': 'normal'})
lognormal = pd.DataFrame({'value': np.random.lognormal(mu, sigma, 1000), 'type': 'lognormal'})

# create a pandas data frame
df = pd.concat([normal, lognormal])

# %%
from bokeh.charts import Histogram
hist = charts.Histogram(df, values='value', color='type', bins=50, legend=True)
show(hist)
# Out:
#     <div class="plotdiv" id="5763222e-e2a1-4eb3-9501-f51558c7d279"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5763222e-e2a1-4eb3-9501-f51558c7d279");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5763222e-e2a1-4eb3-9501-f51558c7d279' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9e39d2a5-5be1-4a1e-b02c-157fd795228a":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6900935d-9f09-43a6-9bf1-b07e21b8e56a","type":"Rect"},{"attributes":{"data_source":{"id":"00bee4a7-3e34-4106-9796-4abd53bac194","type":"ColumnDataSource"},"glyph":{"id":"d76ff34b-4970-4784-a35e-60dc14973c63","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"10183b46-0905-47d5-bd8a-30f53120d1fa","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"479632d2-e25c-41ba-a46b-1bf0601de2b6","type":"Rect"},{"attributes":{"data_source":{"id":"6b531eab-5a70-4a3b-a267-971e6a5f905b","type":"ColumnDataSource"},"glyph":{"id":"dd47d4f1-646f-4d47-87e8-abb037a68e12","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"435acb77-3871-4ad2-b060-e026f2108d48","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"63a3c618-6081-4854-967b-30be67f3bb47","type":"ColumnDataSource"},"glyph":{"id":"37cff346-8c55-49d9-93c3-54032b6bcdab","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6e912d43-e86d-45d8-827a-2ce222352db7","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1c6936c1-04ed-405c-ac55-409bdcdbc0fb","type":"ColumnDataSource"},"glyph":{"id":"bffa5cc0-d1ca-4e00-a1d2-b97f7f397bc4","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"38436eae-8b7f-40b3-83ce-4a6a066d936d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"type":"lognormal"}],"color":["#f22c40"],"fill_alpha":[0.6],"height":[5.0],"line_alpha":[1.0],"line_color":["black"],"type":["lognormal"],"width":[0.09500000000000003],"x":["2.415"],"y":[2.5]}},"id":"34f4a2d4-3363-4ccf-aff4-e13358eaa9dd","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ebcf11e5-00ba-4a6b-b294-54694dd659c0","type":"Rect"},{"attributes":{"data_source":{"id":"1a8a1731-a801-48ef-ab7a-7ed55ee2fe9e","type":"ColumnDataSource"},"glyph":{"id":"6900935d-9f09-43a6-9bf1-b07e21b8e56a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d8910a93-71e4-4b56-ba3c-90c480b7dadb","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"162f84bd-12c7-41c0-ae19-5077eb36d120","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"species":"setosa"}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[0.09999999999999998],"line_alpha":[1.0],"line_color":["black"],"species":["setosa"],"width":[0.8],"x":["setosa"],"y":[0.25]}},"id":"e91e94f7-10bd-493f-9d94-05e61438de87","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5b45c134-0a80-4e10-9737-9274925beb64","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{ ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[23]</strong>&gt;</code></p>

# %% [markdown]
# ## Line plot

# %%
from bokeh.sampledata.us_marriages_divorces import data as marriages_divorces
marriages_divorces.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867     357000     10000    36970000                 9.7
# 1  1868     345000     10000    37885000                 9.1
# 2  1869     348000     11000    38870000                 9.0
# 3  1870     352000     11000    39905000                 8.8
# 4  1871     359000     12000    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
charts.Line?

# %%
p = charts.Line(
    marriages_divorces, ylabel='per 1000 people', legend='top_left', x='Year', 
    y=['Marriages_per_1000', 'Divorces_per_1000']
)
show(p)
# Out:
#     <div class="plotdiv" id="bae4f2eb-d81d-4d0d-8344-dd2cf3726d58"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bae4f2eb-d81d-4d0d-8344-dd2cf3726d58");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bae4f2eb-d81d-4d0d-8344-dd2cf3726d58' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"70e412b9-3e19-490f-b57e-dc94b460ae67":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6900935d-9f09-43a6-9bf1-b07e21b8e56a","type":"Rect"},{"attributes":{"data_source":{"id":"00bee4a7-3e34-4106-9796-4abd53bac194","type":"ColumnDataSource"},"glyph":{"id":"d76ff34b-4970-4784-a35e-60dc14973c63","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"10183b46-0905-47d5-bd8a-30f53120d1fa","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c6b3a051-1d51-499c-ba70-bd0bac13efb1","type":"ColumnDataSource"},"glyph":{"id":"1c9d853c-5188-413c-bd7f-783bc6b9ca1a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4b9b34c2-3a40-45b2-8647-16adcb399826","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"479632d2-e25c-41ba-a46b-1bf0601de2b6","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"83e0420c-b61b-4629-9dc2-13f544030012","type":"Rect"},{"attributes":{"data_source":{"id":"cdb44d61-bb51-4e00-8f01-207700c0136a","type":"ColumnDataSource"},"glyph":{"id":"dd4b7236-a0c7-4830-88e7-9020877da32b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"dabc4a66-9d1d-4187-b2dd-abaf7b4a76df","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"63a3c618-6081-4854-967b-30be67f3bb47","type":"ColumnDataSource"},"glyph":{"id":"37cff346-8c55-49d9-93c3-54032b6bcdab","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6e912d43-e86d-45d8-827a-2ce222352db7","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1c6936c1-04ed-405c-ac55-409bdcdbc0fb","type":"ColumnDataSource"},"glyph":{"id":"bffa5cc0-d1ca-4e00-a1d2-b97f7f397bc4","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"38436eae-8b7f-40b3-83ce-4a6a066d936d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"type":"lognormal"}],"color":["#f22c40"],"fill_alpha":[0.6],"height":[5.0],"line_alpha":[1.0],"line_color":["black"],"type":["lognormal"],"width":[0.09500000000000003],"x":["2.415"],"y":[2.5]}},"id":"34f4a2d4-3363-4ccf-aff4-e13358eaa9dd","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ebcf11e5-00ba-4a6b-b294-54694dd659c0","type":"Rect"},{"attributes":{"data_source":{"id":"1a8a1731-a801-48ef-ab7a-7ed55ee2fe9e","type":"ColumnDataSource"},"glyph":{"id":"6900935d-9f09-43a6-9bf1-b07e21b8e56a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d8910a93-71e4-4b56-ba3c-90c480b7dadb","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"origin":1,"yr":79}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[21.5],"line_alpha":[1.0],"line_color":["white"],"origin":[1],"width":[0.8],"x":["79"],"y":[10.75],"yr":[79]}},"id":"08dc3dff-0f32-444a-a8f7-59774548fdb2","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field": ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[29]</strong>&gt;</code></p>

# %% [markdown]
# ## Area plot

# %% [markdown]
# Get the number of models by year

# %%
df2 = autompg[['yr', 'origin']].groupby(
    ['yr', 'origin']).aggregate(len).reset_index()
df2.columns = ['yr', 'origin', 'model_count']
df3 = df2.replace({'origin':{1:'US', 2:'Europe', 3:'Japan'}})

# %%
model_origin = df3.pivot(
    index='yr', columns='origin', values='model_count').reset_index()

# %%
p = charts.Area(
    model_origin, x='yr', y=['US', 'Europe', 'Japan'], legend='top_right',
    xlabel='year', ylabel='number of models',
    title="Auto model origin by country")
show(p)
# Out:
#     <div class="plotdiv" id="34e5c80c-d07b-49c0-aa90-df84d01e2762"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById